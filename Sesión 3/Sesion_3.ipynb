# %%
# Día 3

# Gráficas y datos

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
M, L, T= np.loadtxt('tabla1.txt', unpack=True)

# %%
plt.plot(M,L,"b+")
plt.grid()
plt.xlabel("Dato 1")
plt.ylabel("Dato 2")
plt.title("Ejemplo de gráfico")
plt.show()

# %%
id, M, L, T = np.loadtxt('tabla2.txt', unpack=True)

# %%
plt.rcParams.update({'font.size': 14})
plt.plot(T,L,"b+")
plt.grid()
plt.xscale("log")
plt.yscale("log")
plt.xlim(50000,4000)
plt.xlabel("Temperatura eff")
plt.ylabel("Luminosidad")
plt.title("Diagrama Hertzprung-Russell")
plt.show()

# %% [markdown]
# Base de datos a utilizar: http://www.isthe.com/chongo/tech/astro/HR-temp-mass-table-byhrclass.html
